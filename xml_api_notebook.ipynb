# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen

# %%
url = "https://data.qld.gov.au/dataset/air-quality-monitoring-live-data-feed/resource/50410fbe-8766-45cd-a259-c4c1f3c89dd1"
#url = 'https://ehp.qld.gov.au/cgi-bin/air/xml.php?category=1&region=ALL'
url_result = urlopen(url)
raw_data = url_result.read()
xml_soup = soup(raw_data, 'xml')
print(xml_soup)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE html>
# <!--[if IE 9]> <html lang="en_AU" class="ie9"> <![endif]--><!--[if gt IE 8]><!--><html lang="en_AU"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="_csrf_token" name="csrf_field_name"/>
# <meta content="IjY5NjY4ZDc1NjNjMzQyYWViMDYxYWY3ZGUxNjQ4ZWI3ZjViMTE3MGUi.aC8hgA.PXp8Rz60TLAa0k8DHD0ci5aOWCA" name="_csrf_token"/>
# <meta content="ckan 2.10.7" name="generator"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport">
# <meta content="corporateName=The State of Queensland; jurisdiction=Queensland" name="DCTERMS.publisher" scheme="AGLSTERMS.AglsAgent"/>
# <meta content="Queensland" name="DCTERMS.jurisdiction" scheme="AGLSTERMS.AglsJuri"/>
# <meta content="Text" name="DCTERMS.type" scheme="DCTERMS.DCMIType"/>
# <meta content="Air quality - Queensland" name="DCTERMS.title"/>
# ...

# %% [markdown]
# The example url for pulling from an api no longer exists and none of the alternative urls work either.  Extremely outdated.   Will continue on with the local file verion.  Should be the same except doing a file open instead of a urlopen.
